# %% [markdown]
# ### Librerías

# %%
import matplotlib.pyplot as plt   # librería para graficar
import numpy as np                # librería para manejo de vectores y utilidades matemáticas

# %% [markdown]
# # Funciones algebraicas

# %% [markdown]
# ### Función lineal
#
# Tiene la forma de $$f(x)=mx + b$$ donde $m$ y $b$  $\in R$.
#
# $m$ puede ser calculada por: $$m=\frac{y_{2}-y_{1}}{x_{2}-x_{1}}$$
#
# y $b$ es el punto de corte con el eje $y$. Su dominio es $Dom_{f} = (-\infty, \infty)$. Su imagen es $Im_{f} = (-\infty, \infty)$

# %%
def f(m,x,b):
    return m * x + b

res = 100

m = -2

b = 5

x = np.linspace(-10.0, 10.0, num=res)

y = f(m,x,b)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %% [markdown]
# ### Función Polinómicas
#
# Tiene la forma de $$P(x)=a_{n}x^{n} + a_{n-1}x^{n-1}+...+a_{2}x^{2}+a_{1}x + a_{1}$$
#
# a una función que tiene esta forma se le llama polinomio de grado $n$. A los elementos $a$ los llamaremoc coeficientes donde $a \in R$.
#
# **Por ejemplo:**
#
# $$P(x)= 2x^{7} - x^{4} + 3x^{2} + 4$$
#
# que es un polinómio de grado 7.
#
#
# ### Funciones potencia
#
# Hay unas funciones que son un caso particular de las funciones polinómicas que son las funciones potencia, las cuales tienen la forma:
#
#
# $$f(x)= x^{a}, a \in R$$
#
#
# **Por ejemplo:**
#
# $$f(x)= x^{2}$$
#
# El dominio de $f(x)=x^{2}$ es $Dom_{f} = (-\infty, \infty)$. Su imagen es $Im_{f} = [0, \infty)$
#
# Dada cualquier funcion algebraica esta satisface una ecuacion polinomica

# %%
def f(x):
    return x**2

res = 100

x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %%
def f(x):
    return 2*x**7 - x**4 + 3*x**2 + 4

res = 100

x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %%
def f(x):
    return 2*x**8 - x**4 + 3*x**2 + 4

res = 100

x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.margins(x=-0.1, y=1)
ax.plot(x, y)
ax.grid()
# ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %%
def f(x):
    return 2*x**8 - x**4 + 3*x**2 + 4

res = 100

x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
# ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %%
def f(x):
  return 2 * x**7 - x**4 + 3 * x**2 + 4
N=100

x = np.linspace(-100.0, 100.0, num=N)
y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %% [markdown]
# # Funciones trascendentes
#
# Son funciones que no pueden ser expresadas con polinomios.

# %% [markdown]
# ### Funciones trigonométricas
#
# Algunos ejemplos son las funciones $cos(x)$, $sen(x)$ y $tan(x)$

# %%
def f(x):
    return np.cos(x)

res = 100

x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %%
def f(x):
    return np.sin(x)

res = 100

x = np.linspace(-10.0, 10.0, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %% [markdown]
# ### Función exponencial
#
# Tienen la forma de $$f(x)=a^x$$ donde la base $a$ es una constante positiva. Un gran ejemplo de una función exponencial es usando la base como el número de euler:
#
# $$f(x)=e^x$$

# %%
def f(x):
    return 2**x

res = 100

x = np.linspace(-5, 5, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.margins(x=-0.35, y=0.35)

ax.plot(x, y)
ax.set_xlim([-3.5,3.5])
ax.set_ylim([-1,5])
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %%
def f(x):
    return np.e**x

res = 100

x = np.linspace(-5, 5, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.margins(x=-0.35, y=0.35)

ax.plot(x, y)
ax.set_xlim([-3.5,3.5])
ax.set_ylim([-1,5])
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %%
def f(x):
    return 10**x

res = 100

x = np.linspace(-5, 5, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.margins(x=-0.35, y=0.35)

ax.plot(x, y)
ax.set_xlim([-3.5,3.5])
ax.set_ylim([-1,5])
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %% [markdown]
# ### Función logaritmo
#
# El logaritmo está definido por la **realación**:
#
# $$log_{b}(x) = n \Longleftrightarrow x=b^n$$
#
# donde:
#
#
#
# *   $b$ es la base.
# *   $n$ es el exponente al que está elevado la base.
# *   $x$ es el resultado de elevar la base $b$ al exponente $n$
#
# **Ejemplo:**
#
# Teniendo b=2 y n=8, entonces:
#
# $$2^8=256$$
#
# Por lo que $x=256$. Calculando el logaritmo base 2 de $x$ es:
#
# $$log_{2}(256) = 8$$

# %% [markdown]
# El logaritmo no toma valores negativos ni cero debido a su relacion con el exponente, obtener un exponente de un numero que al elevarlo a ese numero de cero es imposible, usando valores infinitecimalmente pequeños nos podemos aproximar al cero pero nunca sera cero.

# %%
def f(x):
    return np.log2(x)

res = 100

x = np.linspace(0.01, 256, num=res)

y = f(x)

fig, ax = plt.subplots()

ax.plot(x, y)

ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')
plt.show()

# %% [markdown]
# # Función seccionada
#
# Son funciones que tienen diferentes valores definidos por un intervalo. Por ejemplo la función escalón de Heaviside:
#
# $$
# H(x) =
#      \begin{cases}
#         0, &\quad \text{para, } x < 0 \\
#         1,  &\quad\text{para. } x \ge 0 \\
#      \end{cases}
# $$

# %%
def H(x):
    y = np.zeros(len(x))
    for idx, x in enumerate(x):
        if x >= 0:
            y[idx] = 1.0
    return y

res = 100

x = np.linspace(-10.0, 10.0, num=res)

y = H(x)

fig, ax = plt.subplots()

ax.plot(x, y)

ax.grid()
# ax.axhline(y=0, color='r')
# ax.axvline(x=0, color='r')
plt.show()
